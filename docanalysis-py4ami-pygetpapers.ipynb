# %% [markdown]
# <a href="https://colab.research.google.com/github/semanticClimate/colab-docanalysis-py4ami-pygetpapers/blob/main/docanalysis-py4ami-pygetpapers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Package installation: `docanalysis` , `py4ami` and `pygetpapers`

# %%
# !pip install docanalysis
# !git clone https://github.com/petermr/semanticClimate.git
# !pip install -r /content/semanticClimate/keyword_extraction/code/requirement.txt
import nltk
nltk.download('')
# !python -m spacy download en_core_web_lg
import os
# !pip install py4ami==0.0.35
# !pip install pipreqs
# !pip install pygetpapers
# !python -m spacy download en_core_web_lg
# Out:
# Collecting docanalysis
#   Downloading docanalysis-0.3.0.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Collecting abbreviations (from docanalysis)
#   Downloading abbreviations-0.2.5-py3-none-any.whl (5.7 kB)
# Collecting beautifulsoup4==4.10.0 (from docanalysis)
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.4/97.4 kB 5.0 MB/s eta 0:00:00
# Collecting braceexpand==0.1.7 (from docanalysis)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting coloredlogs==15.0.1 (from docanalysis)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.6 MB/s eta 0:00:00
# Collecting ConfigArgParse==1.5.3 (from docanalysis)
#   Downloading ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Collecting lxml==4.7.1 (from docanalysis)
#   Downloading lxml-4.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 44.4 MB/s eta 0:00:00
# Collecting nltk==3.6.7 (from docanalysis)
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 69.8 MB/s eta 0:00:00
# Collecting pandas==1.3.4 (from docanalysis)
#   Downloading pandas-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 27.5 MB/s eta 0:00:00
# Collecting pygetpapers (from docanalysis)
#   Downloading pygetpapers-1.2.5-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.4/111.4 kB 14.1 MB/s eta 0:00:00
# Collecting pytest==6.2.5 (from docanalysis)
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 kB 28.5 MB/s eta 0:00:00
# Collecting setuptools==60.3.1 (from docanalysis)
#   Downloading setuptools-60.3.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.0/954.0 kB 64.3 MB/s eta 0:00:00
# Collecting spacy==3.0.7 (from docanalysis)
#   Downloading spacy-3.0.7.tar.gz (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.0/988.0 kB 62.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tkinterweb==3.10.7 (from docanalysis)
#   Downloading tkinterweb-3.10.7.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tqdm==4.62.3 (from docanalysis)
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.10.0->docanalysis) (2.5)
# Collecting humanfriendly>=9.1 (from coloredlogs==15.0.1->docanalysis)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.6.7->docanalysis) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk==3.6.7->docanalysis) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.6.7->docanalysis) (2023.12.25)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.4->docanalysis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.4->docanalysis) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.4->docanalysis) (1.25.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from pytest==6.2.5->docanalysis) (23.2.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.10/dist-packages (from pytest==6.2.5->docanalysis) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from pytest==6.2.5->docanalysis) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from pytest==6.2.5->docanalysis) (1.4.0)
# Collecting py>=1.8.2 (from pytest==6.2.5->docanalysis)
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pytest==6.2.5->docanalysis) (0.10.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (3.0.9)
# Collecting thinc<8.1.0,>=8.0.3 (from spacy==3.0.7->docanalysis)
#   Using cached thinc-8.0.17-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (659 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (0.7.11)
# Collecting wasabi<1.1.0,>=0.8.1 (from spacy==3.0.7->docanalysis)
#   Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (2.0.10)
# Collecting typer<0.4.0,>=0.3.0 (from spacy==3.0.7->docanalysis)
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting pathy>=0.3.5 (from spacy==3.0.7->docanalysis)
#   Using cached pathy-0.11.0-py3-none-any.whl (47 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 (from spacy==3.0.7->docanalysis)
#   Using cached pydantic-1.8.2-py3-none-any.whl (126 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.0.7->docanalysis) (3.1.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from tkinterweb==3.10.7->docanalysis) (9.4.0)
# Collecting xmltodict (from pygetpapers->docanalysis)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting habanero (from pygetpapers->docanalysis)
#   Downloading habanero-1.2.6-py2.py3-none-any.whl (30 kB)
# Collecting arxiv (from pygetpapers->docanalysis)
#   Downloading arxiv-2.1.0-py3-none-any.whl (11 kB)
# Collecting dict2xml (from pygetpapers->docanalysis)
#   Downloading dict2xml-1.7.5-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy==3.0.7->docanalysis) (6.4.0)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.3.5->spacy==3.0.7->docanalysis)
#   Using cached pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy==3.0.7->docanalysis) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.4->docanalysis) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (2024.2.2)
# Collecting click (from nltk==3.6.7->docanalysis)
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 10.1 MB/s eta 0:00:00
# Collecting feedparser==6.0.10 (from arxiv->pygetpapers->docanalysis)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 10.0 MB/s eta 0:00:00
# Collecting sgmllib3k (from feedparser==6.0.10->arxiv->pygetpapers->docanalysis)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy==3.0.7->docanalysis) (2.1.5)
# Building wheels for collected packages: docanalysis, spacy, tkinterweb, sgmllib3k
#   Building wheel for docanalysis (setup.py) ... done
#   Created wheel for docanalysis: filename=docanalysis-0.3.0-py3-none-any.whl size=34766 sha256=82df1ad0fb5d02b5709df3c093e7344a321af453e008fedc277c1267c2858985
#   Stored in directory: /root/.cache/pip/wheels/dc/92/b8/f09bf8a5f6903903ddbdba7c2c2d090ad1b1cc6b0e9212dca7
#   Building wheel for spacy (pyproject.toml) ... done
#   Created wheel for spacy: filename=spacy-3.0.7-cp310-cp310-linux_x86_64.whl size=25974885 sha256=1ba2c7d605c9d75f3b48fb6bf0742b2919d39506c6b1eca5c63375562c272fe9
#   Stored in directory: /root/.cache/pip/wheels/61/af/8f/215a6e6c2ced660e9324d651f73ea90bdbb1408c748a7e0a9f
#   Building wheel for tkinterweb (setup.py) ... done
#   Created wheel for tkinterweb: filename=tkinterweb-3.10.7-py3-none-any.whl size=1063338 sha256=11bf9e2fd7fed79402d31eb3fbab4b58f8d67bfc412d2dbcb6c5c88ed05c7d8f
#   Stored in directory: /root/.cache/pip/wheels/be/cb/e9/ab965ddd9fbe72d1175820f135d18d5ea669ea4e5c7d81297b
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=8797a17711cc9661bd33ce5a04e0357eafddef53a591f7c7bf97b6eee1ed649b
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built docanalysis spacy tkinterweb sgmllib3k
# Installing collected packages: wasabi, sgmllib3k, braceexpand, xmltodict, tqdm, tkinterweb, setuptools, pydantic, py, pathlib-abc, lxml, humanfriendly, feedparser, dict2xml, ConfigArgParse, click, beautifulsoup4, abbreviations, typer, thinc, pytest, pandas, nltk, habanero, coloredlogs, arxiv, pygetpapers, pathy, spacy, docanalysis
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.2
#     Uninstalling wasabi-1.1.2:
#       Successfully uninstalled wasabi-1.1.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.1
#     Uninstalling pydantic-2.6.1:
#       Successfully uninstalled pydantic-2.6.1
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.4
#     Uninstalling lxml-4.9.4:
#       Successfully uninstalled lxml-4.9.4
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.3
#     Uninstalling thinc-8.2.3:
#       Successfully uninstalled thinc-8.2.3
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.4.4
#     Uninstalling pytest-7.4.4:
#       Successfully uninstalled pytest-7.4.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.4
#     Uninstalling spacy-3.7.4:
#       Successfully uninstalled spacy-3.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# flask 2.2.5 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# bigframes 0.21.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 1.3.4 which is incompatible.
# cvxpy 1.3.3 requires setuptools>65.5.1, but you have setuptools 60.3.1 which is incompatible.
# dask 2023.8.1 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# distributed 2023.8.1 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# en-core-web-sm 3.7.1 requires spacy<3.8.0,>=3.7.2, but you have spacy 3.0.7 which is incompatible.
# fiona 1.9.5 requires click~=8.0, but you have click 7.1.2 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 1.3.4 which is incompatible.
# inflect 7.0.0 requires pydantic>=1.9.1, but you have pydantic 1.8.2 which is incompatible.
# mizani 0.9.3 requires pandas>=1.3.5, but you have pandas 1.3.4 which is incompatible.
# pip-tools 6.13.0 requires click>=8, but you have click 7.1.2 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.3.4 which is incompatible.
# xarray 2023.7.0 requires pandas>=1.4, but you have pandas 1.3.4 which is incompatible.
# yfinance 0.2.36 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.10.0 which is incompatible.
# yfinance 0.2.36 requires lxml>=4.9.1, but you have lxml 4.7.1 which is incompatible.
# Successfully installed ConfigArgParse-1.5.3 abbreviations-0.2.5 arxiv-2.1.0 beautifulsoup4-4.10.0 braceexpand-0.1.7 click-7.1.2 coloredlogs-15.0.1 dict2xml-1.7.5 docanalysis-0.3.0 feedparser-6.0.10 habanero-1.2.6 humanfriendly-10.0 lxml-4.7.1 nltk-3.6.7 pandas-1.3.4 pathlib-abc-0.1.1 pathy-0.11.0 py-1.11.0 pydantic-1.8.2 pygetpapers-1.2.5 pytest-6.2.5 setuptools-60.3.1 sgmllib3k-1.0.0 spacy-3.0.7 thinc-8.0.17 tkinterweb-3.10.7 tqdm-4.62.3 typer-0.3.2 wasabi-0.10.1 xmltodict-0.13.0
# Cloning into 'semanticClimate'...
# remote: Enumerating objects: 58560, done.
# remote: Counting objects: 100% (11881/11881), done.
# remote: Compressing objects: 100% (3300/3300), done.
# remote: Total 58560 (delta 8615), reused 11676 (delta 8462), pack-reused 46679
# Receiving objects: 100% (58560/58560), 1.41 GiB | 23.07 MiB/s, done.
# Resolving deltas: 100% (28299/28299), done.
# Updating files: 100% (42415/42415), done.
# Collecting git+https://github.com/LIAAD/yake (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2))
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-6r9p4chj
#   Running command git clone --filter=blob:none --quiet https://github.com/LIAAD/yake /tmp/pip-req-build-6r9p4chj
#   Resolved https://github.com/LIAAD/yake to commit 0fa58cceb465162b6bd0cab7ec967edeb907fbcc
#   Preparing metadata (setup.py) ... done
# Collecting multi_rake (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1))
#   Downloading multi_rake-0.0.2-py3-none-any.whl (31 kB)
# Collecting summa (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 3))
#   Downloading summa-1.2.0.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting keybert (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4))
#   Downloading keybert-0.8.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (1.3.4)
# Collecting tkinterhtml==0.7 (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 6))
#   Downloading tkinterhtml-0.7.zip (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.2/930.2 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyamiimage (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading pyamiimage-0.0.13.tar.gz (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.0/179.0 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber==0.7.4 (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8))
#   Downloading pdfplumber-0.7.4-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.6 MB/s eta 0:00:00
# Collecting pdfminer3 (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9))
#   Downloading pdfminer3-2018.12.3.0.tar.gz (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfminer.six==20220524 (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8))
#   Downloading pdfminer.six-20220524-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (9.4.0)
# Collecting Wand>=0.6.7 (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8))
#   Downloading Wand-0.6.13-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (42.0.3)
# Requirement already satisfied: numpy>=1.14.4 in /usr/local/lib/python3.10/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (1.25.2)
# Collecting pycld2>=0.41 (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1))
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 16.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyrsistent>=0.14.2 (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1))
#   Downloading pyrsistent-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2018.6.6 in /usr/local/lib/python3.10/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (2023.12.25)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (0.9.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (7.1.2)
# Collecting segtok (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2))
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (3.2.1)
# Collecting jellyfish (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2))
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from summa->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 3)) (1.11.4)
# Collecting sentence-transformers>=0.3.8 (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4))
#   Downloading sentence_transformers-2.4.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.2.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (13.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (2023.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.7.1)
# Collecting pytesseract (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting easyocr (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading easyocr-1.7.1-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 46.1 MB/s eta 0:00:00
# Requirement already satisfied: pytest in /usr/local/lib/python3.10/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (6.2.5)
# Requirement already satisfied: scikit_image in /usr/local/lib/python3.10/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.19.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (60.3.1)
# Collecting skan (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading skan-0.11.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.5 MB/s eta 0:00:00
# Collecting sknw (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading sknw-0.15-py3-none-any.whl (4.6 kB)
# Collecting pycryptodome (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9))
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.2 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (2.4.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (5.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.16.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.37.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.62.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.20.3)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.10/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.16.0+cu121)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.9.0.80)
# Collecting python-bidi (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (6.0.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.3)
# Collecting pyclipper (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 63.1 MB/s eta 0:00:00
# Collecting ninja (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7))
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 32.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (23.2.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.10/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.4.0)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.11.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.10.2)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit_image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit_image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.5.0)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.58.1)
# Collecting pandas (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5))
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.10/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.1.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.12.1)
# Collecting tzdata>=2022.7 (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.9.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.1.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.41.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=2.6->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.1.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.4.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.1.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.3.0)
# Building wheels for collected packages: tkinterhtml, yake, summa, keybert, pyamiimage, pdfminer3, pycld2
#   Building wheel for tkinterhtml (setup.py) ... done
#   Created wheel for tkinterhtml: filename=tkinterhtml-0.7-py3-none-any.whl size=928089 sha256=3dd7a89bafd61d48f2688bcb77a98e83128aaccbd394b25abc5440854a54c097
#   Stored in directory: /root/.cache/pip/wheels/73/85/a5/d57d954e28c38345bf659d83d0eea8badb971b0d83d8234a14
#   Building wheel for yake (setup.py) ... done
#   Created wheel for yake: filename=yake-0.4.8-py2.py3-none-any.whl size=62016 sha256=ab385a5ae001857ffc27ec329b494df19d8687f9754a4b8579c6bbffe2dcdb04
#   Stored in directory: /tmp/pip-ephem-wheel-cache-03p8e6et/wheels/10/9d/33/6a3358fd876c3d7c6c5c139d1496eb4b1618c7d0e15c375584
#   Building wheel for summa (setup.py) ... done
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54406 sha256=c9008450c4b046138c23e60a62a0008e3cb56cc7c0d62442b29d9796a35413e3
#   Stored in directory: /root/.cache/pip/wheels/4a/ca/c5/4958614cfba88ed6ceb7cb5a849f9f89f9ac49971616bc919f
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.4-py3-none-any.whl size=39220 sha256=9656e4e46495c7ab5cb0d488634943e1fa251e556e6d9b3a94864535998f2d8c
#   Stored in directory: /root/.cache/pip/wheels/97/ef/4c/6588bd7072b0cc04225b40e639b991e49ebd4e21fb81f0acee
#   Building wheel for pyamiimage (setup.py) ... done
#   Created wheel for pyamiimage: filename=pyamiimage-0.0.13-py3-none-any.whl size=95914 sha256=92baa105633bcaf3afcaca0cf4d3c42a7f7bd532118873a1a4191ff81ebf9b1c
#   Stored in directory: /root/.cache/pip/wheels/7b/3e/d1/8f1090441a945fd95fc0b473b3caff3c176cc3189601a0ef3b
#   Building wheel for pdfminer3 (setup.py) ... done
#   Created wheel for pdfminer3: filename=pdfminer3-2018.12.3.0-py3-none-any.whl size=117824 sha256=738f2ac4f55fdbdd5b221722966c020b05c9c19f96183b6c5b01edd3f37a3df9
#   Stored in directory: /root/.cache/pip/wheels/37/71/87/7a05ed89df2d26f343b71bcc89c8257fdfc1541a79d79736c2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp310-cp310-linux_x86_64.whl size=9904045 sha256=cc8973b95623b85d6f4f446afb371dbcd517a9305b0be7f66ab477111b78fd76
#   Stored in directory: /root/.cache/pip/wheels/be/81/31/240c89c845e008a93d98542325270007de595bfd356eb0b06c
# Successfully built tkinterhtml yake summa keybert pyamiimage pdfminer3 pycld2
# Installing collected packages: Wand, tkinterhtml, pyclipper, pycld2, ninja, tzdata, segtok, python-bidi, pytesseract, pyrsistent, pycryptodome, jellyfish, yake, summa, sknw, pdfminer3, pandas, multi_rake, skan, pdfminer.six, pdfplumber, easyocr, sentence-transformers, pyamiimage, keybert
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.21.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# docanalysis 0.3.0 requires pandas==1.3.4, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# yfinance 0.2.36 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.10.0 which is incompatible.
# yfinance 0.2.36 requires lxml>=4.9.1, but you have lxml 4.7.1 which is incompatible.
# Successfully installed Wand-0.6.13 easyocr-1.7.1 jellyfish-1.0.3 keybert-0.8.4 multi_rake-0.0.2 ninja-1.11.1.1 pandas-2.2.1 pdfminer.six-20220524 pdfminer3-2018.12.3.0 pdfplumber-0.7.4 pyamiimage-0.0.13 pycld2-0.41 pyclipper-1.3.0.post5 pycryptodome-3.20.0 pyrsistent-0.20.0 pytesseract-0.3.10 python-bidi-0.4.2 segtok-1.5.11 sentence-transformers-2.4.0 skan-0.11.1 sknw-0.15 summa-1.2.0 tkinterhtml-0.7 tzdata-2024.1 yake-0.4.8
# [nltk_data] Error loading : Package '' not found in index
# 2024-02-27 09:16:01.431227: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 09:16:01.431319: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 09:16:01.435163: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 09:16:01.449114: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 09:16:03.022094: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl#egg=en_core_web_lg==3.0.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.8/778.8 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.0.0) (3.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.10)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (60.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (23.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2024.2.2)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.1.5)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Collecting py4ami==0.0.35
#   Downloading py4ami-0.0.35.tar.gz (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 22.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: py4ami
#   Building wheel for py4ami (setup.py) ... done
#   Created wheel for py4ami: filename=py4ami-0.0.35-py3-none-any.whl size=11511566 sha256=5ea3c9f00bd3c87cad44253b9f24fc2cb37771920a7f499c544280337d206778
#   Stored in directory: /root/.cache/pip/wheels/23/b7/93/b00cf274d12250ce37c742b572fdb218808850f52a81c0bcca
# Successfully built py4ami
# Installing collected packages: py4ami
# Successfully installed py4ami-0.0.35
# Collecting pipreqs
#   Downloading pipreqs-0.5.0-py3-none-any.whl (33 kB)
# Collecting docopt==0.6.2 (from pipreqs)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ipython==8.12.3 (from pipreqs)
#   Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
# ...
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (3.1.3)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (5.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (2.1.5)
# Collecting mistune<4,>=2.0.3 (from nbconvert<8.0.0,>=7.11.0->pipreqs)
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (5.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython==8.12.3->pipreqs) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (4.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (6.1.12)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (4.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython==8.12.3->pipreqs) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.3->pipreqs) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yarg==0.1.9->pipreqs) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yarg==0.1.9->pipreqs) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yarg==0.1.9->pipreqs) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yarg==0.1.9->pipreqs) (2024.2.2)
# Collecting executing>=1.2.0 (from stack-data->ipython==8.12.3->pipreqs)
#   Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython==8.12.3->pipreqs)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Collecting pure-eval (from stack-data->ipython==8.12.3->pipreqs)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (0.18.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (23.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.8.2)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (6.3.2)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13724 sha256=383246fbfbbef6a8eda9b97c5a8976d8977360c0ee48b0b2faa84a3f271dcb64
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: pure-eval, docopt, mistune, jedi, executing, asttokens, yarg, stack-data, ipython, nbconvert, pipreqs
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.5.4
#     Uninstalling nbconvert-6.5.4:
#       Successfully uninstalled nbconvert-6.5.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.3 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# Successfully installed asttokens-2.4.1 docopt-0.6.2 executing-2.0.1 ipython-8.12.3 jedi-0.19.1 mistune-3.0.2 nbconvert-7.16.1 pipreqs-0.5.0 pure-eval-0.2.2 stack-data-0.6.3 yarg-0.1.9
# Requirement already satisfied: pygetpapers in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (2.2.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (4.7.1)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (0.13.0)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (1.5.3)
# Requirement already satisfied: habanero in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (1.2.6)
# Requirement already satisfied: arxiv in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (2.1.0)
# Requirement already satisfied: dict2xml in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (1.7.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (4.62.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from pygetpapers) (15.0.1)
# Requirement already satisfied: feedparser==6.0.10 in /usr/local/lib/python3.10/dist-packages (from arxiv->pygetpapers) (6.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pygetpapers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pygetpapers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pygetpapers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pygetpapers) (2024.2.2)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser==6.0.10->arxiv->pygetpapers) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->pygetpapers) (10.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->pygetpapers) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pygetpapers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pygetpapers) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->pygetpapers) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pygetpapers) (1.16.0)
# 2024-02-27 09:17:29.772041: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 09:17:29.772113: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 09:17:29.773694: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 09:17:29.782157: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 09:17:31.409257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl#egg=en_core_web_lg==3.0.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting en-core-web-lg==3.0.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.0.0) (3.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.10)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (60.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (23.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2024.2.2)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %% [markdown]
# ## Saving literatures from EPMC for the specific query

# %%
# !docanalysis --run_pygetpapers -q "chromatin interaction" -k 20 --project_name chromatin_interaction
# !pygetpapers -q "chromatin interaction" -k 20 -o "chromatin_interaction" -c --makehtml -x --save_query
# Out:
# 2024-02-27 09:25:58.329076: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 09:25:58.329147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 09:25:58.330573: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 09:25:58.338588: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 09:25:59.807122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INFO: Total Hits are 0
# WARNING: Could not find more papers
# Traceback (most recent call last):
#   File "/usr/local/bin/docanalysis", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/docanalysis/docanalysis.py", line 195, in main
#     calldocanalysis.handlecli()
#   File "/usr/local/lib/python3.10/dist-packages/docanalysis/docanalysis.py", line 187, in handlecli
#     self.entity_extraction.extract_entities_from_papers(args.project_name, args.dictionary, search_sections=args.search_section, entities=args.entities, query=args.query, hits=args.hits,
#   File "/usr/local/lib/python3.10/dist-packages/docanalysis/entity_extraction.py", line 135, in extract_entities_from_papers
#     self.run_pygetpapers(query, hits, corpus_path)
#   File "/usr/local/lib/python3.10/dist-packages/docanalysis/entity_extraction.py", line 216, in run_pygetpapers
#     pygetpapers_call.run_command(
#   File "/usr/local/lib/python3.10/dist-packages/pygetpapers/pygetpapers.py", line 294, in run_command
#     self.runs_pygetpapers_for_given_args(got_parameters)
#   File "/usr/local/lib/python3.10/dist-packages/pygetpapers/pygetpapers.py", line 312, in runs_pygetpapers_for_given_args
#     api_handler.check_query_logic_and_run()
#   File "/usr/local/lib/python3.10/dist-packages/pygetpapers/pygetpapers.py", line 204, in check_query_logic_and_run
#     self.api.apipaperdownload(self.query_namespace)
#   File "/usr/local/lib/python3.10/dist-packages/pygetpapers/repository/europe_pmc.py", line 324, in apipaperdownload
#     self.run_eupmc_query_and_get_metadata(
#   File "/usr/local/lib/python3.10/dist-packages/pygetpapers/repository/europe_pmc.py", line 289, in run_eupmc_query_and_get_metadata
#     metadata_dictionary = self.query(
#   File "/usr/local/lib/python3.10/dist-packages/pygetpapers/repository/europe_pmc.py", line 125, in query
#     list_of_paper_metadata = self._remove_extra_papers_from_list(cutoff_size, list_of_paper_metadata)
# UnboundLocalError: local variable 'list_of_paper_metadata' referenced before assignment
# INFO: Total Hits are 194118
# 20it [00:00, 71089.90it/s]
# INFO: Saving XML files to /content/chromatin_interaction/*/fulltext.xml
# 100% 20/20 [00:42<00:00,  2.11s/it]

# %% [markdown]
# ## making section to save the xml and html output

# %%
# !docanalysis --project_name chromatin_interaction --make_section
# Out:
# 2024-02-27 09:27:21.246593: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 09:27:21.246657: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 09:27:21.248157: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 09:27:21.256407: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 09:27:22.722606: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# WARNING: Making sections in /content/chromatin_interaction/PMC8785527/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC8785527/fulltext.xml /content/chromatin_interaction/PMC8785527/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC10627812/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC10627812/fulltext.xml /content/chromatin_interaction/PMC10627812/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC8221632/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC8221632/fulltext.xml /content/chromatin_interaction/PMC8221632/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9129085/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9129085/fulltext.xml /content/chromatin_interaction/PMC9129085/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC10793909/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC10793909/fulltext.xml /content/chromatin_interaction/PMC10793909/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9398308/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9398308/fulltext.xml /content/chromatin_interaction/PMC9398308/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC10517636/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC10517636/fulltext.xml /content/chromatin_interaction/PMC10517636/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9016624/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9016624/fulltext.xml /content/chromatin_interaction/PMC9016624/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9647974/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9647974/fulltext.xml /content/chromatin_interaction/PMC9647974/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC10313346/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC10313346/fulltext.xml /content/chromatin_interaction/PMC10313346/sections
# WARNING: /content/chromatin_interaction/PMC8351913/fulltext.xml is empty
# WARNING: Making sections in /content/chromatin_interaction/PMC8855862/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC8855862/fulltext.xml /content/chromatin_interaction/PMC8855862/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC10688478/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC10688478/fulltext.xml /content/chromatin_interaction/PMC10688478/sections
# WARNING: /content/chromatin_interaction/PMC9643445/fulltext.xml is empty
# WARNING: Making sections in /content/chromatin_interaction/PMC8424394/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC8424394/fulltext.xml /content/chromatin_interaction/PMC8424394/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC10714240/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC10714240/fulltext.xml /content/chromatin_interaction/PMC10714240/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9352921/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9352921/fulltext.xml /content/chromatin_interaction/PMC9352921/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9667886/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9667886/fulltext.xml /content/chromatin_interaction/PMC9667886/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9202886/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9202886/fulltext.xml /content/chromatin_interaction/PMC9202886/sections
# WARNING: Making sections in /content/chromatin_interaction/PMC9104700/fulltext.xml
# INFO: wrote XML sections for /content/chromatin_interaction/PMC9104700/fulltext.xml /content/chromatin_interaction/PMC9104700/sections

# %% [markdown]
# ## Abbreviation extraction

# %%
# !docanalysis --project_name chromatin_interaction --extract_abb /content/all_abbreviations
# Out:
# 2024-02-27 09:27:54.680864: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 09:27:54.680938: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 09:27:54.682361: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 09:27:54.690628: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 09:27:56.182809: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 100% 22/22 [00:00<00:00, 664.29it/s]
# 0it [00:00, ?it/s]
# 100% 26/26 [00:00<00:00, 1590.21it/s]
# 100% 24/24 [00:00<00:00, 439.90it/s]
# 100% 11/11 [00:00<00:00, 1632.60it/s]
# 100% 113/113 [00:00<00:00, 927.79it/s]
# 100% 2/2 [00:00<00:00, 1637.76it/s]
# 100% 42/42 [00:00<00:00, 976.71it/s]
# 100% 61/61 [00:00<00:00, 952.24it/s]
# 100% 12/12 [00:00<00:00, 1356.79it/s]
# 100% 114/114 [00:00<00:00, 1338.53it/s]
# 100% 229/229 [00:00<00:00, 741.33it/s]
# 100% 14/14 [00:00<00:00, 172.62it/s]
# 100% 18/18 [00:00<00:00, 1116.55it/s]
# 0it [00:00, ?it/s]
# INFO: Found 4152 sentences in the section(s).
# 191it [01:31,  2.09it/s]
# INFO: wrote all abbreviations to ami dict /content/all_abbreviations.xml

# %%
# @title ## Keyword extraction from the literature
# !python /content/semanticClimate/keyword_extraction/code/keyword.py \
--html_path /content/chromatin_interaction/eupmc_result.html \
--saving_path /content/ \
--method 'rake'
# Out:
# 2024-02-27 09:29:54.664615: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 09:29:54.664677: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 09:29:54.666239: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 09:29:56.136014: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# ## Making WordCloud from the keywords

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Step 1: Read the CSV file into a DataFrame
csv_file_path = '/content/Rake_keywords.csv'  # Replace with the path to your CSV file
df = pd.read_csv(csv_file_path)

# Step 2: Extract the keywords from the 'Keyword' column
keywords = df['keyword/phrase'].str.cat(sep=' ')

# Step 3: Preprocess the keywords (optional)
# For example, you can convert text to lowercase:
keywords = keywords.lower()

# Step 4: Define a list of stop words to exclude from the word cloud
stop_words = ['research','system','future','increase','pregnancy', 'chain']  # Add your stop words here

# Step 5: Tokenize the keywords into words
words = keywords.split()

# Step 6: Filter out stop words
filtered_words = [word for word in words if word not in stop_words]

# Step 7: Create a space-separated string of the filtered keywords
filtered_keywords_text = ' '.join(filtered_words)

# Step 8: Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_keywords_text)

# Step 9: Display the word cloud
plt.figure(figsize=(12, 15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# If you want to save the word cloud to a file (e.g., 'wordcloud.png'):
# wordcloud.to_file('wordcloud.png')
